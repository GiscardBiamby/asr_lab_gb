# %% [markdown]
# **Task:**
#
# 😊-------------------------------------------------------
#
# In this lab, you are going to make your speech recognizer. Specifically, given a pretrained wav2vec2 model, you should perform fine-tuning (FT) on your own speech data (English). You are required to collect **20 minutes** of your own voice that is recorded in either clean or noisy background. The content can be in any domains. Please just follow Gopala's voice format that will be given in the next few sections to deal with your voice data. Generally speaking, the duration of each utterance is suggested to be about **2s-5s**. But you can do any numbers. If it is 4s for each utterance, 20 minutes would correspond to about 300 utterances. Once you have 20 minutes data, you should perform 3 sets of experiments independently:
#
# 1. FT on the entire data (20minutes)
# 2. FT on 10 minutes data that is randomly sampled.
# 3. FT on 5 minutes data that is randomly sampled.
#
# For each experiment, please make sure to have train/dev/test split where the suggested ratio is 0.8 : 0.1 : 0.1. Please report WER for both dev and test set. That saying, you need **6 results in total**.
#
# Submission:
# Just **a doc or pdf file** that contains:
#
# (1) Colab links for all experiments. For example, if you do three experiments in three different colabs, just copy and paste all three links. If you just use one colab, then submit one.
#
# (2) Brief introduction of your collected corpus (where and how they were recorded, content domains, number of utterances, etc) and **your own data**! If you follow this code template and also use gdrive, please just copy and paste the gdrive link in the doc.
#
# (3) Brief analysis of the results.
#
# 😊-------------------------------------------------------

# %% [markdown]
# This code template is adapted from HugginFace [wav2vec2 code base](https://huggingface.co/docs/transformers/model_doc/wav2vec2).

# %% [markdown]
# Belowing is an example of performing fine-tuning on Gopala's voice with wav2vec2. You can follow this template and just replace the data with your own voice by following the same data format. So let's get started!

# %% [markdown]
# First, check GPU availablity. You are suggested to upgrade Colab Pro to have access to high-performance GPU. But it is not required.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Dec 21 06:43:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.43.04    Driver Version: 515.43.04    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA TITAN RTX    On   | 00000000:1A:00.0 Off |                  N/A |
# | 41%   31C    P8    11W / 280W |   5584MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA TITAN RTX    On   | 00000000:1B:00.0 Off |                  N/A |
# | 41%   37C    P8    16W / 280W |   6501MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA TITAN RTX    On   | 00000000:1C:00.0 Off |                  N/A |
# | 41%   33C    P8    13W / 280W |     12MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA TITAN RTX    On   | 00000000:1D:00.0 Off |                  N/A |
# | 41%   33C    P8    14W / 280W |     12MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA TITAN RTX    On   | 00000000:1E:00.0 Off |                  N/A |
# | 41%   32C    P8     9W / 280W |     12MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA GeForce ...  On   | 00000000:3D:00.0 Off |                  N/A |
# | 30%   30C    P8     7W / 250W |     12MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA GeForce ...  On   | 00000000:3E:00.0 Off |                  N/A |
# | 30%   29C    P8    10W / 250W |     12MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA GeForce ...  On   | 00000000:3F:00.0 Off |                  N/A |
# | 30%   31C    P8    21W / 250W |     12MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   8  NVIDIA GeForce ...  On   | 00000000:40:00.0 Off |                  N/A |
# | 30%   31C    P8     6W / 250W |     12MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   9  NVIDIA GeForce ...  On   | 00000000:41:00.0 Off |                  N/A |
# | 30%   29C    P8    13W / 250W |     12MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 11MiB |
# |    0   N/A  N/A   1592487      C   ...e/envs/asr_lab/bin/python     5569MiB |
# |    1   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    1   N/A  N/A   2066580      C   ...e/envs/asr_lab/bin/python     6487MiB |
# |    2   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    3   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    4   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    5   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    6   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    7   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    8   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# |    9   N/A  N/A     29777      G   /usr/lib/xorg/Xorg                 10MiB |
# +-----------------------------------------------------------------------------+

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %% [markdown]
# Install both `datasets` and `transformers` from master. Also, we need the `librosa` package to load audio files and the `jiwer` to evaluate our fine-tuned model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric ${}^1$.

# %%
# %%capture
# !pip install datasets==1.18.3
# !pip install transformers==4.17.0
# !pip install jiwer

# %%
from datasets import  load_dataset, load_metric

# from datasets import disable_caching
# disable_caching()

# %% [markdown]
# Below we have already prepared Gopala's voice that is saved in gdrive. Just download it unzip it.

# %%
#download giscard's voice
# !pip install -U --no-cache-dir gdown --pre
# !gdown https://drive.google.com/u/0/uc?id=1BD24lt0Qp6olADXmGnnP85v1iFb6cFEa
# !unzip -o data_giscard.zip
# Out:
# Requirement already satisfied: gdown in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (4.6.0)
# Requirement already satisfied: filelock in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from gdown) (3.8.2)
# Requirement already satisfied: tqdm in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from gdown) (4.64.1)
# Requirement already satisfied: six in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: requests[socks] in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from gdown) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from gdown) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from requests[socks]->gdown) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from requests[socks]->gdown) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1BD24lt0Qp6olADXmGnnP85v1iFb6cFEa
# To: /home/gbiamby/proj/asr_lab_gb/data_giscard.zip
# 100%|███████████████████████████████████████| 92.6M/92.6M [00:00<00:00, 208MB/s]
# Archive:  data_giscard.zip
#   inflating: data_giscard/249.wav
#   inflating: data_giscard/275.wav
#   inflating: data_giscard/513.wav
#   inflating: data_giscard/507.wav
#   inflating: data_giscard/261.wav
#   inflating: data_giscard/16.wav
#   inflating: data_giscard/103.wav
#   inflating: data_giscard/117.wav
#   inflating: data_giscard/498.wav
#   inflating: data_giscard/329.wav
#   inflating: data_giscard/301.wav
#   inflating: data_giscard/467.wav
#   inflating: data_giscard/473.wav
#   inflating: data_giscard/315.wav
#   inflating: data_giscard/472.wav
#   inflating: data_giscard/314.wav
#   inflating: data_giscard/300.wav
#   inflating: data_giscard/466.wav
#   inflating: data_giscard/328.wav
#   inflating: data_giscard/499.wav
#   inflating: data_giscard/116.wav
#   inflating: data_giscard/102.wav
#   inflating: data_giscard/17.wav
#   inflating: data_giscard/506.wav
#   inflating: data_giscard/260.wav
#   inflating: data_giscard/274.wav
#   inflating: data_giscard/512.wav
#   inflating: data_giscard/248.wav
#   inflating: data_giscard/289.wav
#   inflating: data_giscard/538.wav
#   inflating: data_giscard/262.wav
#   inflating: data_giscard/504.wav
#   inflating: data_giscard/510.wav
#   inflating: data_giscard/276.wav
#   inflating: data_giscard/15.wav
#   inflating: data_giscard/29.wav
#   inflating: data_giscard/128.wav
#   inflating: data_giscard/valid.csv
#   inflating: data_giscard/114.wav
#   inflating: data_giscard/100.wav
#   inflating: data_giscard/458.wav
#   inflating: data_giscard/316.wav
#   inflating: data_giscard/470.wav
#   inflating: data_giscard/464.wav
#   inflating: data_giscard/302.wav
#   inflating: data_giscard/465.wav
#   inflating: data_giscard/303.wav
#   inflating: data_giscard/317.wav
#   inflating: data_giscard/471.wav
#   inflating: data_giscard/459.wav
#   inflating: data_giscard/101.wav
#   inflating: data_giscard/115.wav
#   inflating: data_giscard/129.wav
#   inflating: data_giscard/28.wav
#   inflating: data_giscard/14.wav
#   inflating: data_giscard/511.wav
#   inflating: data_giscard/277.wav
#   inflating: data_giscard/263.wav
#   inflating: data_giscard/505.wav
#   inflating: data_giscard/539.wav
#   inflating: data_giscard/288.wav
#   inflating: data_giscard/298.wav
#   inflating: data_giscard/501.wav
#   inflating: data_giscard/267.wav
#   inflating: data_giscard/273.wav
#   inflating: data_giscard/515.wav
#   inflating: data_giscard/529.wav
#   inflating: data_giscard/38.wav
#   inflating: data_giscard/10.wav
#   inflating: data_giscard/111.wav
#   inflating: data_giscard/105.wav
#   inflating: data_giscard/139.wav
#   inflating: data_giscard/475.wav
#   inflating: data_giscard/313.wav
#   inflating: data_giscard/307.wav
#   inflating: data_giscard/461.wav
#   inflating: data_giscard/449.wav
#   inflating: data_giscard/448.wav
#   inflating: data_giscard/306.wav
#   inflating: data_giscard/460.wav
#   inflating: data_giscard/474.wav
#   inflating: data_giscard/312.wav
#   inflating: data_giscard/138.wav
#   inflating: data_giscard/104.wav
#   inflating: data_giscard/110.wav
#   inflating: data_giscard/11.wav
#   inflating: data_giscard/39.wav
#   inflating: data_giscard/528.wav
#   inflating: data_giscard/272.wav
#   inflating: data_giscard/514.wav
#   inflating: data_giscard/500.wav
#   inflating: data_giscard/266.wav
#   inflating: data_giscard/299.wav
#   inflating: data_giscard/516.wav
#   inflating: data_giscard/270.wav
#   inflating: data_giscard/264.wav
#   inflating: data_giscard/502.wav
#   inflating: data_giscard/258.wav
#   inflating: data_giscard/13.wav
#   inflating: data_giscard/106.wav
#   inflating: data_giscard/112.wav
#   inflating: data_giscard/489.wav
#   inflating: data_giscard/462.wav
#   inflating: data_giscard/304.wav
#   inflating: data_giscard/310.wav
#   inflating: data_giscard/476.wav
#   inflating: data_giscard/338.wav
#   inflating: data_giscard/339.wav
#   inflating: data_giscard/311.wav
#   inflating: data_giscard/477.wav
#   inflating: data_giscard/463.wav
#   inflating: data_giscard/305.wav
#   inflating: data_giscard/488.wav
#   inflating: data_giscard/113.wav
#   inflating: data_giscard/107.wav
#   inflating: data_giscard/12.wav
#   inflating: data_giscard/259.wav
#   inflating: data_giscard/265.wav
#   inflating: data_giscard/503.wav
#   inflating: data_giscard/517.wav
#   inflating: data_giscard/271.wav
#   inflating: data_giscard/558.wav
#   inflating: data_giscard/570.wav
#   inflating: data_giscard/216.wav
#   inflating: data_giscard/202.wav
#   inflating: data_giscard/564.wav
#   inflating: data_giscard/61.wav
#   inflating: data_giscard/75.wav
#   inflating: data_giscard/49.wav
#   inflating: data_giscard/148.wav
#   inflating: data_giscard/160.wav
#   inflating: data_giscard/174.wav
#   inflating: data_giscard/389.wav
#   inflating: data_giscard/438.wav
#   inflating: data_giscard/404.wav
#   inflating: data_giscard/362.wav
#   inflating: data_giscard/376.wav
#   inflating: data_giscard/410.wav
#   inflating: data_giscard/377.wav
#   inflating: data_giscard/411.wav
#   inflating: data_giscard/405.wav
#   inflating: data_giscard/363.wav
#   inflating: data_giscard/439.wav
#   inflating: data_giscard/388.wav
#   inflating: data_giscard/175.wav
#   inflating: data_giscard/161.wav
#   inflating: data_giscard/149.wav
#   inflating: data_giscard/48.wav
#   inflating: data_giscard/74.wav
#   inflating: data_giscard/60.wav
#   inflating: data_giscard/203.wav
#   inflating: data_giscard/565.wav
#   inflating: data_giscard/571.wav
#   inflating: data_giscard/217.wav
#   inflating: data_giscard/559.wav
#   inflating: data_giscard/598.wav
#   inflating: data_giscard/229.wav
#   inflating: data_giscard/567.wav
#   inflating: data_giscard/201.wav
#   inflating: data_giscard/215.wav
#   inflating: data_giscard/573.wav
#   inflating: data_giscard/test.csv
#   inflating: data_giscard/188.wav
#   inflating: data_giscard/76.wav
#   inflating: data_giscard/62.wav
#   inflating: data_giscard/177.wav
#   inflating: data_giscard/89.wav
#   inflating: data_giscard/163.wav
#   inflating: data_giscard/349.wav
#   inflating: data_giscard/413.wav
#   inflating: data_giscard/375.wav
#   inflating: data_giscard/361.wav
#   inflating: data_giscard/407.wav
#   inflating: data_giscard/360.wav
#   inflating: data_giscard/406.wav
#   inflating: data_giscard/412.wav
#   inflating: data_giscard/374.wav
#   inflating: data_giscard/348.wav
#   inflating: data_giscard/162.wav
#   inflating: data_giscard/176.wav
#   inflating: data_giscard/88.wav
#   inflating: data_giscard/63.wav
#   inflating: data_giscard/189.wav
#   inflating: data_giscard/77.wav
#   inflating: data_giscard/214.wav
#   inflating: data_giscard/572.wav
#   inflating: data_giscard/200.wav
#   inflating: data_giscard/228.wav
#   inflating: data_giscard/599.wav
#   inflating: data_giscard/589.wav
#   inflating: data_giscard/204.wav
#   inflating: data_giscard/562.wav
#   inflating: data_giscard/576.wav
#   inflating: data_giscard/210.wav
#   inflating: data_giscard/238.wav
#   inflating: data_giscard/9.wav
#   inflating: data_giscard/73.wav
#   inflating: data_giscard/199.wav
#   inflating: data_giscard/67.wav
#   inflating: data_giscard/172.wav
#   inflating: data_giscard/166.wav
#   inflating: data_giscard/98.wav
#   inflating: data_giscard/370.wav
#   inflating: data_giscard/416.wav
#   inflating: data_giscard/402.wav
#   inflating: data_giscard/364.wav
#   inflating: data_giscard/358.wav
#   inflating: data_giscard/359.wav
#   inflating: data_giscard/403.wav
#   inflating: data_giscard/365.wav
#   inflating: data_giscard/371.wav
#   inflating: data_giscard/417.wav
#   inflating: data_giscard/167.wav
#   inflating: data_giscard/99.wav
#   inflating: data_giscard/173.wav
#   inflating: data_giscard/198.wav
#   inflating: data_giscard/66.wav
#   inflating: data_giscard/72.wav
#   inflating: data_giscard/8.wav
#   inflating: data_giscard/239.wav
#   inflating: data_giscard/577.wav
#   inflating: data_giscard/211.wav
#   inflating: data_giscard/205.wav
#   inflating: data_giscard/563.wav
#   inflating: data_giscard/588.wav
#   inflating: data_giscard/213.wav
#   inflating: data_giscard/575.wav
#   inflating: data_giscard/561.wav
#   inflating: data_giscard/207.wav
#   inflating: data_giscard/549.wav
#   inflating: data_giscard/58.wav
#   inflating: data_giscard/64.wav
#   inflating: data_giscard/70.wav
#   inflating: data_giscard/165.wav
#   inflating: data_giscard/171.wav
#   inflating: data_giscard/159.wav
#   inflating: data_giscard/398.wav
#   inflating: data_giscard/367.wav
#   inflating: data_giscard/401.wav
#   inflating: data_giscard/415.wav
#   inflating: data_giscard/373.wav
#   inflating: data_giscard/429.wav
#   inflating: data_giscard/428.wav
#   inflating: data_giscard/414.wav
#   inflating: data_giscard/372.wav
#   inflating: data_giscard/366.wav
#   inflating: data_giscard/400.wav
#   inflating: data_giscard/399.wav
#   inflating: data_giscard/158.wav
#   inflating: data_giscard/170.wav
#   inflating: data_giscard/164.wav
#   inflating: data_giscard/71.wav
#   inflating: data_giscard/65.wav
#   inflating: data_giscard/59.wav
#   inflating: data_giscard/548.wav
#   inflating: data_giscard/560.wav
#   inflating: data_giscard/206.wav
#   inflating: data_giscard/212.wav
#   inflating: data_giscard/574.wav
#   inflating: data_giscard/592.wav
#   inflating: data_giscard/586.wav
#   inflating: data_giscard/579.wav
#   inflating: data_giscard/551.wav
#   inflating: data_giscard/237.wav
#   inflating: data_giscard/223.wav
#   inflating: data_giscard/545.wav
#   inflating: data_giscard/40.wav
#   inflating: data_giscard/54.wav
#   inflating: data_giscard/6.wav
#   inflating: data_giscard/182.wav
#   inflating: data_giscard/68.wav
#   inflating: data_giscard/196.wav
#   inflating: data_giscard/83.wav
#   inflating: data_giscard/97.wav
#   inflating: data_giscard/169.wav
#   inflating: data_giscard/141.wav
#   inflating: data_giscard/155.wav
#   inflating: data_giscard/380.wav
#   inflating: data_giscard/394.wav
#   inflating: data_giscard/419.wav
#   inflating: data_giscard/425.wav
#   inflating: data_giscard/343.wav
#   inflating: data_giscard/357.wav
#   inflating: data_giscard/431.wav
#   inflating: data_giscard/356.wav
#   inflating: data_giscard/430.wav
#   inflating: data_giscard/424.wav
#   inflating: data_giscard/342.wav
#   inflating: data_giscard/418.wav
#   inflating: data_giscard/395.wav
#   inflating: data_giscard/381.wav
#   inflating: data_giscard/154.wav
#   inflating: data_giscard/140.wav
#   inflating: data_giscard/96.wav
#   inflating: data_giscard/168.wav
#   inflating: data_giscard/82.wav
#   inflating: data_giscard/69.wav
#   inflating: data_giscard/197.wav
#   inflating: data_giscard/183.wav
#   inflating: data_giscard/55.wav
#   inflating: data_giscard/7.wav
#   inflating: data_giscard/41.wav
#   inflating: data_giscard/222.wav
#   inflating: data_giscard/544.wav
#   inflating: data_giscard/550.wav
#   inflating: data_giscard/236.wav
#   inflating: data_giscard/578.wav
#   inflating: data_giscard/587.wav
#   inflating: data_giscard/593.wav
#   inflating: data_giscard/585.wav
#   inflating: data_giscard/591.wav
#   inflating: data_giscard/208.wav
#   inflating: data_giscard/546.wav
#   inflating: data_giscard/220.wav
#   inflating: data_giscard/234.wav
#   inflating: data_giscard/552.wav
#   inflating: data_giscard/5.wav
#   inflating: data_giscard/57.wav
#   inflating: data_giscard/43.wav
#   inflating: data_giscard/195.wav
#   inflating: data_giscard/181.wav
#   inflating: data_giscard/94.wav
#   inflating: data_giscard/80.wav
#   inflating: data_giscard/156.wav
#   inflating: data_giscard/142.wav
#   inflating: data_giscard/397.wav
#   inflating: data_giscard/383.wav
#   inflating: data_giscard/368.wav
#   inflating: data_giscard/432.wav
#   inflating: data_giscard/354.wav
#   inflating: data_giscard/340.wav
#   inflating: data_giscard/426.wav
#   inflating: data_giscard/341.wav
#   inflating: data_giscard/427.wav
#   inflating: data_giscard/433.wav
#   inflating: data_giscard/355.wav
#   inflating: data_giscard/369.wav
#   inflating: data_giscard/382.wav
#   inflating: data_giscard/396.wav
#   inflating: data_giscard/143.wav
#   inflating: data_giscard/157.wav
#   inflating: data_giscard/81.wav
#   inflating: data_giscard/95.wav
#   inflating: data_giscard/180.wav
#   inflating: data_giscard/194.wav
#   inflating: data_giscard/42.wav
#   inflating: data_giscard/4.wav
#   inflating: data_giscard/56.wav
#   inflating: data_giscard/235.wav
#   inflating: data_giscard/553.wav
#   inflating: data_giscard/547.wav
#   inflating: data_giscard/221.wav
#   inflating: data_giscard/209.wav
#   inflating: data_giscard/590.wav
#   inflating: data_giscard/584.wav
#   inflating: data_giscard/580.wav
#   inflating: data_giscard/594.wav
#   inflating: data_giscard/225.wav
#   inflating: data_giscard/543.wav
#   inflating: data_giscard/557.wav
#   inflating: data_giscard/231.wav
#   inflating: data_giscard/219.wav
#   inflating: data_giscard/190.wav
#   inflating: data_giscard/184.wav
#   inflating: data_giscard/52.wav
#   inflating: data_giscard/0.wav
#   inflating: data_giscard/46.wav
#   inflating: data_giscard/153.wav
#   inflating: data_giscard/147.wav
#   inflating: data_giscard/91.wav
#   inflating: data_giscard/85.wav
#   inflating: data_giscard/392.wav
#   inflating: data_giscard/386.wav
#   inflating: data_giscard/351.wav
#   inflating: data_giscard/437.wav
#   inflating: data_giscard/423.wav
#   inflating: data_giscard/345.wav
#   inflating: data_giscard/379.wav
#   inflating: data_giscard/378.wav
#   inflating: data_giscard/422.wav
#   inflating: data_giscard/344.wav
#   inflating: data_giscard/350.wav
#   inflating: data_giscard/436.wav
#   inflating: data_giscard/387.wav
#   inflating: data_giscard/393.wav
#   inflating: data_giscard/84.wav
#   inflating: data_giscard/90.wav
#   inflating: data_giscard/146.wav
#   inflating: data_giscard/152.wav
#   inflating: data_giscard/47.wav
#   inflating: data_giscard/53.wav
#   inflating: data_giscard/1.wav
#   inflating: data_giscard/185.wav
#   inflating: data_giscard/191.wav
#   inflating: data_giscard/218.wav
#   inflating: data_giscard/556.wav
#   inflating: data_giscard/230.wav
#   inflating: data_giscard/224.wav
#   inflating: data_giscard/542.wav
#   inflating: data_giscard/595.wav
#   inflating: data_giscard/581.wav
#   inflating: data_giscard/597.wav
#   inflating: data_giscard/583.wav
#   inflating: data_giscard/232.wav
#   inflating: data_giscard/554.wav
#   inflating: data_giscard/540.wav
#   inflating: data_giscard/226.wav
#   inflating: data_giscard/568.wav
#   inflating: data_giscard/79.wav
#   inflating: data_giscard/187.wav
#   inflating: data_giscard/193.wav
#   inflating: data_giscard/45.wav
#   inflating: data_giscard/3.wav
#   inflating: data_giscard/51.wav
#   inflating: data_giscard/144.wav
#   inflating: data_giscard/150.wav
#   inflating: data_giscard/86.wav
#   inflating: data_giscard/178.wav
#   inflating: data_giscard/92.wav
#   inflating: data_giscard/385.wav
#   inflating: data_giscard/391.wav
#   inflating: data_giscard/346.wav
#   inflating: data_giscard/420.wav
#   inflating: data_giscard/434.wav
#   inflating: data_giscard/352.wav
#   inflating: data_giscard/408.wav
#   inflating: data_giscard/409.wav
#   inflating: data_giscard/435.wav
#   inflating: data_giscard/353.wav
#   inflating: data_giscard/347.wav
#   inflating: data_giscard/421.wav
#   inflating: data_giscard/390.wav
#   inflating: data_giscard/384.wav
#   inflating: data_giscard/93.wav
#   inflating: data_giscard/87.wav
#   inflating: data_giscard/179.wav
#   inflating: data_giscard/151.wav
#   inflating: data_giscard/145.wav
#   inflating: data_giscard/2.wav
#   inflating: data_giscard/50.wav
#   inflating: data_giscard/44.wav
#   inflating: data_giscard/192.wav
#   inflating: data_giscard/78.wav
#   inflating: data_giscard/186.wav
#   inflating: data_giscard/569.wav
#   inflating: data_giscard/541.wav
#   inflating: data_giscard/227.wav
#   inflating: data_giscard/233.wav
#   inflating: data_giscard/555.wav
#   inflating: data_giscard/582.wav
#   inflating: data_giscard/596.wav
#   inflating: data_giscard/297.wav
#   inflating: data_giscard/283.wav
#   inflating: data_giscard/268.wav
#   inflating: data_giscard/254.wav
#   inflating: data_giscard/532.wav
#   inflating: data_giscard/train.csv
#   inflating: data_giscard/526.wav
#   inflating: data_giscard/240.wav
#   inflating: data_giscard/23.wav
#   inflating: data_giscard/37.wav
#   inflating: data_giscard/122.wav
#   inflating: data_giscard/136.wav
#   inflating: data_giscard/485.wav
#   inflating: data_giscard/491.wav
#   inflating: data_giscard/308.wav
#   inflating: data_giscard/320.wav
#   inflating: data_giscard/446.wav
#   inflating: data_giscard/452.wav
#   inflating: data_giscard/334.wav
#   inflating: data_giscard/453.wav
#   inflating: data_giscard/335.wav
#   inflating: data_giscard/321.wav
#   inflating: data_giscard/447.wav
#   inflating: data_giscard/309.wav
#   inflating: data_giscard/490.wav
#   inflating: data_giscard/484.wav
#   inflating: data_giscard/137.wav
#   inflating: data_giscard/123.wav
#   inflating: data_giscard/36.wav
#   inflating: data_giscard/22.wav
#   inflating: data_giscard/527.wav
#   inflating: data_giscard/241.wav
#   inflating: data_giscard/255.wav
#   inflating: data_giscard/533.wav
#   inflating: data_giscard/269.wav
#   inflating: data_giscard/282.wav
#   inflating: data_giscard/296.wav
#   inflating: data_giscard/280.wav
#   inflating: data_giscard/294.wav
#   inflating: data_giscard/519.wav
#   inflating: data_giscard/243.wav
#   inflating: data_giscard/525.wav
#   inflating: data_giscard/531.wav
#   inflating: data_giscard/257.wav
#   inflating: data_giscard/34.wav
#   inflating: data_giscard/20.wav
#   inflating: data_giscard/109.wav
#   inflating: data_giscard/135.wav
#   inflating: data_giscard/121.wav
#   inflating: data_giscard/492.wav
#   inflating: data_giscard/486.wav
#   inflating: data_giscard/479.wav
#   inflating: data_giscard/337.wav
#   inflating: data_giscard/451.wav
#   inflating: data_giscard/445.wav
#   inflating: data_giscard/323.wav
#   inflating: data_giscard/444.wav
#   inflating: data_giscard/322.wav
#   inflating: data_giscard/336.wav
#   inflating: data_giscard/450.wav
#   inflating: data_giscard/478.wav
#   inflating: data_giscard/487.wav
#   inflating: data_giscard/493.wav
#   inflating: data_giscard/120.wav
#   inflating: data_giscard/134.wav
#   inflating: data_giscard/108.wav
#   inflating: data_giscard/21.wav
#   inflating: data_giscard/35.wav
#   inflating: data_giscard/530.wav
#   inflating: data_giscard/256.wav
#   inflating: data_giscard/242.wav
#   inflating: data_giscard/524.wav
#   inflating: data_giscard/518.wav
#   inflating: data_giscard/295.wav
#   inflating: data_giscard/281.wav
#   inflating: data_giscard/285.wav
#   inflating: data_giscard/291.wav
#   inflating: data_giscard/520.wav
#   inflating: data_giscard/246.wav
#   inflating: data_giscard/252.wav
#   inflating: data_giscard/534.wav
#   inflating: data_giscard/508.wav
#   inflating: data_giscard/19.wav
#   inflating: data_giscard/31.wav
#   inflating: data_giscard/25.wav
#   inflating: data_giscard/130.wav
#   inflating: data_giscard/124.wav
#   inflating: data_giscard/118.wav
#   inflating: data_giscard/497.wav
#   inflating: data_giscard/483.wav
#   inflating: data_giscard/454.wav
#   inflating: data_giscard/332.wav
#   inflating: data_giscard/326.wav
#   inflating: data_giscard/440.wav
#   inflating: data_giscard/468.wav
#   inflating: data_giscard/469.wav
#   inflating: data_giscard/327.wav
#   inflating: data_giscard/441.wav
#   inflating: data_giscard/455.wav
#   inflating: data_giscard/333.wav
#   inflating: data_giscard/482.wav
#   inflating: data_giscard/496.wav
#   inflating: data_giscard/119.wav
#   inflating: data_giscard/125.wav
#   inflating: data_giscard/131.wav
#   inflating: data_giscard/24.wav
#   inflating: data_giscard/30.wav
#   inflating: data_giscard/18.wav
#   inflating: data_giscard/509.wav
#   inflating: data_giscard/253.wav
#   inflating: data_giscard/535.wav
#   inflating: data_giscard/521.wav
#   inflating: data_giscard/247.wav
#   inflating: data_giscard/290.wav
#   inflating: data_giscard/284.wav
#   inflating: data_giscard/292.wav
#   inflating: data_giscard/286.wav
#   inflating: data_giscard/537.wav
#   inflating: data_giscard/251.wav
#   inflating: data_giscard/245.wav
#   inflating: data_giscard/523.wav
#   inflating: data_giscard/279.wav
#   inflating: data_giscard/26.wav
#   inflating: data_giscard/32.wav
#   inflating: data_giscard/127.wav
#   inflating: data_giscard/133.wav
#   inflating: data_giscard/480.wav
#   inflating: data_giscard/494.wav
#   inflating: data_giscard/443.wav
#   inflating: data_giscard/325.wav
#   inflating: data_giscard/331.wav
#   inflating: data_giscard/457.wav
#   inflating: data_giscard/319.wav
#   inflating: data_giscard/318.wav
#   inflating: data_giscard/330.wav
#   inflating: data_giscard/456.wav
#   inflating: data_giscard/442.wav
#   inflating: data_giscard/324.wav
#   inflating: data_giscard/495.wav
#   inflating: data_giscard/481.wav
#   inflating: data_giscard/132.wav
#   inflating: data_giscard/126.wav
#   inflating: data_giscard/33.wav
#   inflating: data_giscard/27.wav
#   inflating: data_giscard/278.wav
#   inflating: data_giscard/244.wav
#   inflating: data_giscard/522.wav
#   inflating: data_giscard/536.wav
#   inflating: data_giscard/250.wav
#   inflating: data_giscard/287.wav
#   inflating: data_giscard/293.wav

# %% [markdown]
# **Have a look at data_gopala folder!!** Your speech data is also suggested to follow the same format. Specifically, all you need is just a folder that contains wav files as well as csv files for train/dev/test respectively.

# %% [markdown]
# After replacing Gopala's voice with yours, no addtional efforts are needed afterwards. Just finish the fine-tuning experiments.

# %%
data = load_dataset("data_giscard")
# Out:
# Using custom data configuration data_giscard-be6af9f1796bc21f
# Reusing dataset csv (/home/gbiamby/.cache/huggingface/datasets/csv/data_giscard-be6af9f1796bc21f/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'text', 'file_exists'],
#         num_rows: 479
#     })
#     test: Dataset({
#         features: ['file', 'text', 'file_exists'],
#         num_rows: 60
#     })
#     validation: Dataset({
#         features: ['file', 'text', 'file_exists'],
#         num_rows: 60
#     })
# })

# %%
data["train"][0]
# Out:
# {'file': 'data_giscard/139.wav',
#  'text': 'That is, the force on its ropes was the equivalent of dangling from their ends an eleven ton steel block.',
#  'file_exists': True}

# %% [markdown]
# Make sure your have train/dev/test split.

# %% [markdown]
# Let's write a short function to display some random samples of the dataset and run it a couple of times to get a feeling for the transcriptions.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML


def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset) - 1)
        while pick in picks:
            pick = random.randint(0, len(dataset) - 1)
        picks.append(pick)

    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(data["validation"].remove_columns(["file"]), num_examples=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>file_exists</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>It was called the Indian Institute of Technology.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The Dutchman laughed again, but nervously, as if deciding whether it was better to be mistaken for a German or a fool.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>It's too goddamn windy out there.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Pen computing was a version of the Palm Pilot, ahead of its time.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Surely, it would have been easy enough for Kleiner Perkins or NEA to announce that they were backing someone else to do the same thing as Clark.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>They did not cling to the past mindlessly.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>The IITs became the funnel through which young Indians who finished high in a national standardized test passed on their way into Nehru's game of catch-up ball.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Thanks for getting the NEA and KPCB groups together to share ideas.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>After all, the idea was simple: eliminate the paperwork, the waiting around, and the market illogic from the U.S.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Even before we left the canal and passed through the locks into the North Sea, the report lost its credibility.</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_random_elements(data["train"].remove_columns(["file"]), num_examples=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>file_exists</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>E-mail made it easier.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>They were ferociously, recklessly competitive.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kittu was in the sixth grade, and his cousin was a pretty young woman.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Why Jim Clark was so worthy of study was another matter, and I'll come to that soon enough.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Once he had identified the new new thing, all he needed was some really smart, passionate engineers to chase after it and make it happen.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>He never seriously believed that Netscape's share price would reach $100.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>There was no question of his suppressing the urge; it was as if someone had pushed a button on the computer that instructed the man to be sick.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>It was a single great, messy experiment, which, in retrospect, was bound not to end well.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>I remember that I decided right then whatever I did next it was going to be with the Web.</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>It took about a minute and a half before the first Dutch boatyard worker leaned over the safety ropes and vomited the Saint Nick's cake he'd been served an hour before.</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that the transcriptions contain some special characters, such as `,.?!;:`. Without a language model, it is much harder to classify speech chunks to such special characters because they don't really correspond to a characteristic sound unit. *E.g.*, the letter `"s"` has a more or less clear sound, whereas the special character `"."` does not.
# Also in order to understand the meaning of a speech signal, it is usually not necessary to include special characters in the transcription.
#
# In addition, we normalize the text to only have lower case letters and append a word separator token at the end.

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\@\(\)]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower() + " "
    return batch

# %%
data = data.map(remove_special_characters)
# Out:
# Parameter 'function'=<function remove_special_characters at 0x7f0748302550> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
show_random_elements(data["train"].remove_columns(["file"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>file_exists</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>specifically he wanted to be able to dial into his boat over the internet from his desk in silicon valley and sail it across the san francisco bay</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>health care system would have dared to make such a grandiose statement</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>its lack of any higher purpose made its ultimate failure even more absurd</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>when hyperion left the seawall behind it put itself at the mercy of a furious north sea</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>these schools and their departments had their own informal hierarchy</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>on the atlantic crossing hyperion would carry only the captain and his seven crew members one or two computer programmers clark and me</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>i said that that was because it was the biggest sloop ever built</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>she talked about how he had these twelveinch spectacles and so on and so forth</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>email made it easier</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>his eyes moved from the hull to the mast and from the mast to the boom and from the boom to the sails which unfurled would cover a football field</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_random_elements(data["validation"].remove_columns(["file"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>file_exists</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>maybe somewhere in a footnote it would be mentioned that he came from nothing grew up poor dropped out of high school and made himself three or four billion dollars</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>i assumed it was netscape that took up most of his energy</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>the trouble was that whether or not hugh knew it clark now was in control of hugh</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>but they were as immune as people can be to the allure of a new way of doing things</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>as it happened clark had a motive for reconsidering his irritation with kramlich he was now even more irritated with john doerr</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>so far as kittu was concerned he'd lived his life on a high wire without a safety net</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>what's the worst weather you ever tested a sailboat in</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>when i arrived that morning of the first north sea trial wolter huisman was standing on the deck beneath the mast</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>he couldn't have known it at the time but his success put him on a collision course with jim clark</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>the steady stream of engineers out of silicon graphics and into netscape just before netscape went public prompted ed mccracken's lawyers to write clark nasty letters</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Good! This looks better. We have removed most special characters from transcriptions and normalized them to lower-case only.
#
# In CTC, it is common to classify speech chunks into letters, so we will do the same here.
# Let's extract all distinct letters of the training and test data and build our vocabulary from this set of letters.
#
# We write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.
# It is important to pass the argument `batched=True` to the `map(...)` function so that the mapping function has access to all transcriptions at once.

# %%
def extract_all_chars(batch):
    all_text = " ".join(batch["text"])
    vocab = list(set(all_text))
    return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocabs = data.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=data.column_names["train"], load_from_cache_file=False)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# Now, we create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
print(len(vocab_dict))
vocab_dict
# Out:
# 41
# {'w': 0,
#  'i': 1,
#  'q': 2,
#  'b': 3,
#  'l': 4,
#  'n': 5,
#  'm': 6,
#  'j': 7,
#  's': 8,
#  'p': 9,
#  'z': 10,
#  'v': 11,
#  'y': 12,
#  'r': 13,
#  'f': 14,
#  'a': 15,
#  'd': 16,
#  "'": 17,
#  '0': 18,
#  '2': 19,
#  'k': 20,
#  ' ': 21,
#  '5': 22,
#  'x': 23,
#  '$': 24,
#  'c': 25,
#  '4': 26,
#  '9': 27,
#  '3': 28,
#  'é': 29,
#  'e': 30,
#  '7': 31,
#  'h': 32,
#  't': 33,
#  'g': 34,
#  '6': 35,
#  'u': 36,
#  'o': 37,
#  '8': 38,
#  '/': 39,
#  '1': 40}

# %% [markdown]
# Cool, we see that all letters of the alphabet occur in the dataset (which is not really surprising) and we also extracted the special characters `" "` and `'`. Note that we did not exclude those special characters because:
#
# - The model has to learn to predict when a word finished or else the model prediction would always be a sequence of chars which would make it impossible to separate words from each other.
# - In English, we need to keep the `'` character to differentiate between words, *e.g.*, `"it's"` and `"its"` which have very different meanings.

# %% [markdown]
# To make it clearer that `" "` has its own token class, we give it a more visible character `|`. In addition, we also add an "unknown" token so that the model can later deal with characters not encountered in training set.
#
# Finally, we also add a padding token that corresponds to CTC's "*blank token*". The "blank token" is a core component of the CTC algorithm. For more information, please take a look at the "Alignment" section [here](https://distill.pub/2017/ctc/).

# %%
if " " in vocab_dict:
    vocab_dict["|"] = vocab_dict[" "]
    del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 43

# %% [markdown]
# Cool, now our vocabulary is complete and consists of 30 tokens, which means that the linear layer that we will add on top of the pretrained Wav2Vec2 checkpoint will have an output dimension of 30.

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %% [markdown]
# The [pretrained Wav2Vec2 checkpoint]( ) maps the speech signal to a sequence of context representations as illustrated in the figure above. A fine-tuned Wav2Vec2 checkpoint needs to map this sequence of context representations to its corresponding transcription so that a linear layer has to be added on top of the transformer block (shown in yellow). This linear layer is used to classifies each context representation to a token class analogous how, *e.g.*, after pretraining a linear layer is added on top of BERT's embeddings for further classification - *cf.* with *"BERT"* section of this [blog post](https://huggingface.co/blog/warm-starting-encoder-decoder).
#
# The output size of this layer corresponds to the number of tokens in the vocabulary, which does **not** depend on Wav2Vec2's pretraining task, but only on the labeled dataset used for fine-tuning.

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %% [markdown]
# # Training_args
#
# This training_args does not mean we are going to train the model. We have to move this part here to avoid crash issues. If you are going tune the hyper-parameters to get better WER, just modify the arguments here.

# %%
repo_name = "wav2vec2-giscard"
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir=repo_name,
    group_by_length=True,
    per_device_train_batch_size=16,
    evaluation_strategy="steps",
    num_train_epochs=160,
    fp16=True,
    gradient_checkpointing=True,
    save_steps=50,
    eval_steps=50,
    logging_steps=50,
    learning_rate=1e-4,
    weight_decay=0.005,
    warmup_steps=50,
    save_total_limit=2,
)

# %% [markdown]
# ### Create Wav2Vec2 Feature Extractor

# %% [markdown]
# A Wav2Vec2 feature extractor object requires the following parameters to be instantiated:
#
# - `feature_size`: Speech models take a sequence of feature vectors as an input. While the length of this sequence obviously varies, the feature size should not. In the case of Wav2Vec2, the feature size is 1 because the model was trained on the raw speech signal ${}^2$.
# - `sampling_rate`: The sampling rate at which the model is trained on.
# - `padding_value`: For batched inference, shorter inputs need to be padded with a specific value
# - `do_normalize`: Whether the input should be *zero-mean-unit-variance* normalized or not. Usually, speech models perform better when normalizing the input
# - `return_attention_mask`: Whether the model should make use of an `attention_mask` for batched inference. In general, models should **always** make use of the `attention_mask` to mask padded tokens. However, due to a very specific design choice of `Wav2Vec2`'s "base" checkpoint, better results are achieved when using no `attention_mask`. This is **not** recommended for other speech models. For more information, one can take a look at [this](https://github.com/pytorch/fairseq/issues/3227) issue. **Important** If you want to use this notebook to fine-tune [large-lv60](https://huggingface.co/facebook/wav2vec2-large-lv60), this parameter should be set to `True`.

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)

# %% [markdown]
# Great, Wav2Vec2's feature extraction pipeline is thereby fully defined!
#
# To make the usage of Wav2Vec2 as user-friendly as possible, the feature extractor and tokenizer are *wrapped* into a single `Wav2Vec2Processor` class so that one only needs a `model` and `processor` object.

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# Next, we can prepare the dataset.

# %%
data["train"][0]["file"]
# Out:
# 'data_giscard/139.wav'

# %% [markdown]
# Great, let's listen to a couple of audio files to better understand the dataset and verify that the audio was correctly loaded.
#
# **Note**: *You can click the following cell a couple of times to listen to different speech samples.*

# %%
import IPython.display as ipd
import numpy as np
import random
import torchaudio

rand_int = random.randint(0, len(data["train"]))

print(data["train"][rand_int]["text"])
wav, _ = torchaudio.load(data["train"][rand_int]["file"])
ipd.Audio(data=np.asarray(wav), autoplay=True, rate=16000)
# Out:
# they beckoned everyone within five miles to drop his jaw in wonder
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# It can be heard, that the speakers change along with their speaking rate, accent, etc. Overall, the recordings sound relatively clear though, which is to be expected from a read speech corpus.
#
# Let's do a final check that the data is correctly prepared, by printing the shape of the speech input, its transcription, and the corresponding sampling rate.
#
# **Note**: *You can click the following cell a couple of times to verify multiple samples.*

# %% [markdown]
# Finally, we can process the dataset to the format expected by the model for training. We will make use of the `map(...)` function.
#
# First, we load and resample the audio data, simply by calling `batch["audio"]`.
# Second, we extract the `input_values` from the loaded audio file. In our case, the `Wav2Vec2Processor` only normalizes the data. For other speech models, however, this step can include more complex feature extraction, such as [Log-Mel feature extraction](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).
# Third, we encode the transcriptions to label ids.
#
# **Note**: This mapping function is a good example of how the `Wav2Vec2Processor` class should be used. In "normal" context, calling `processor(...)` is redirected to `Wav2Vec2FeatureExtractor`'s call method. When wrapping the processor into the `as_target_processor` context, however, the same method is redirected to `Wav2Vec2CTCTokenizer`'s call method.
# For more information please check the [docs](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#transformers.Wav2Vec2Processor.__call__).

# %%
def prepare_dataset(batch):

    audio, _ = torchaudio.load(batch["file"])
    audio = audio.numpy().reshape(-1)
    batch["input_values"] = audio
    batch["input_length"] = len(batch["input_values"])

    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %% [markdown]
# Let's apply the data preparation function to all examples.

# %%
data = data.map(prepare_dataset, remove_columns=data.column_names["train"], num_proc=4, load_from_cache_file=False)

# %% [markdown]
# **Note**: Currently `datasets` make use of [`torchaudio`](https://pytorch.org/audio/stable/index.html) and [`librosa`](https://librosa.org/doc/latest/index.html) for audio loading and resampling. If you wish to implement your own costumized data loading/sampling, feel free to just make use of the `"path"` column instead and disregard the `"audio"` column.

# %% [markdown]
# Long input sequences require a lot of memory. Since `Wav2Vec2` is based on `self-attention` the memory requirement scales quadratically with the input length for long input sequences (*cf.* with [this](https://www.reddit.com/r/MachineLearning/comments/genjvb/d_why_is_the_maximum_input_sequence_length_of/) reddit post). For this demo, let's filter all sequences that are longer than 4 seconds out of the training dataset.

# %%
max_input_length_in_sec = 8.0
data["train"] = data["train"].filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
data["train"]
# data["train"].filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['input_values', 'input_length', 'labels'],
#     num_rows: 380
# })

# %% [markdown]
# ### Reduce the training set size to 10 minutes (so just reduce it by half)
#
# We do the filtering down here so that we can ensure it happens after the dataset filtering for sample length has already been done (in the cell above).
#
# - The full dataset should be 380 samples (after filtering out any samples >= 8.0s)
# - And the 5 minute dataset should be 95 samples

# %%
import numpy as np
data_size  = len(data["train"])
indexes = np.random.choice(list(range(data_size)), size=int(0.25 * data_size), replace=False)
small_dataset = data["train"].select(indexes)
print(f"Full dataset num_samples: {data_size}, reduced training set num_samples: {len(small_dataset)}")
data["train"] = small_dataset
data["train"]
# Out:
# Full dataset num_samples: 380, reduced training set num_samples: 95
# Dataset({
#     features: ['input_values', 'input_length', 'labels'],
#     num_rows: 95
# })

# %% [markdown]
# Awesome, now we are ready to start training!

# %% [markdown]
# ### Set-up Dataloader
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union


@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(
        self, features: List[Dict[str, Union[List[int], torch.Tensor]]]
    ) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
wer_metric = load_metric("wer")

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.
#
# A logit vector $\mathbf{y}_1$ contains the log-odds for each word in the vocabulary we defined earlier, thus $\text{len}(\mathbf{y}_i) =$ `config.vocab_size`. We are interested in the most likely prediction of the model and thus take the `argmax(...)` of the logits. Also, we transform the encoded labels back to the original string by replacing `-100` with the `pad_token_id` and decoding the ids while making sure that consecutive tokens are **not** grouped to the same token in CTC style ${}^1$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# Now, we can load the pretrained `Wav2Vec2` checkpoint. The tokenizer's `pad_token_id` must be to define the model's `pad_token_id` or in the case of `Wav2Vec2ForCTC` also CTC's *blank token* ${}^2$. To save GPU memory, we enable PyTorch's [gradient checkpointing](https://pytorch.org/docs/stable/checkpoint.html) and also set the loss reduction to "*mean*".

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base",
    ctc_loss_reduction="mean",
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(vocab_dict),
)
# Out:
# /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages/transformers/configuration_utils.py:356: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['project_q.weight', 'quantizer.weight_proj.bias', 'project_hid.bias', 'quantizer.weight_proj.weight', 'project_hid.weight', 'quantizer.codevectors', 'project_q.bias']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = model.cuda()

# %% [markdown]
# ### Training
#
# Typically, it is useful to freeze the encoder for low resource/few show settings.

# %%
model.freeze_feature_encoder()

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer


trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=data["train"],
    eval_dataset=data["validation"],
    tokenizer=processor.feature_extractor,
)
# Out:
# Using amp half precision backend

# %% [markdown]
# ---
#
# ${}^1$ To allow models to become independent of the speaker rate, in CTC, consecutive tokens that are identical are simply grouped as a single token. However, the encoded labels should not be grouped when decoding since they don't correspond to the predicted tokens of the model, which is why the `group_tokens=False` parameter has to be passed. If we wouldn't pass this parameter a word like `"hello"` would incorrectly be encoded, and decoded as `"helo"`.
#
# ${}^2$ The blank token allows the model to predict a word, such as `"hello"` by forcing it to insert the blank token between the two l's. A CTC-conform prediction of `"hello"` of our model would be `[PAD] [PAD] "h" "e" "e" "l" "l" [PAD] "l" "o" "o" [PAD]`.

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %% [markdown]
# Depending on what GPU was allocated to your google colab it might be possible that you are seeing an `"out-of-memory"` error here. In this case, it's probably best to reduce `per_device_train_batch_size` to 16 or even less and eventually make use of [`gradient_accumulation`](https://huggingface.co/transformers/master/main_classes/trainer.html#trainingarguments).

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# /home/gbiamby/mambaforge/envs/asr_lab/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 95
#   Num Epochs = 160
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 960
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: gbiamby. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/home/gbiamby/proj/asr_lab_gb/wandb/run-20221221_064531-38hs00wl</code>
# Syncing run <strong><a href="https://wandb.ai/gbiamby/huggingface/runs/38hs00wl" target="_blank">wav2vec2-giscard</a></strong> to <a href="https://wandb.ai/gbiamby/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#     <div>
#
#       <progress value='960' max='960' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [960/960 11:50, Epoch 160/160]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>9.188600</td>
#       <td>3.192727</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>3.021500</td>
#       <td>2.941292</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.918000</td>
#       <td>2.902615</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.864300</td>
#       <td>2.806029</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.228200</td>
#       <td>1.456440</td>
#       <td>0.869960</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.914400</td>
#       <td>0.887415</td>
#       <td>0.675403</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.432000</td>
#       <td>0.792662</td>
#       <td>0.600806</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.260400</td>
#       <td>0.794611</td>
#       <td>0.592742</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.180000</td>
#       <td>0.768632</td>
#       <td>0.548387</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.145400</td>
#       <td>0.800173</td>
#       <td>0.558468</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.120000</td>
#       <td>0.808471</td>
#       <td>0.557460</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.100300</td>
#       <td>0.818589</td>
#       <td>0.548387</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.082700</td>
#       <td>0.824521</td>
#       <td>0.547379</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.074100</td>
#       <td>0.837952</td>
#       <td>0.534274</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.063500</td>
#       <td>0.834484</td>
#       <td>0.530242</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.058100</td>
#       <td>0.827786</td>
#       <td>0.525202</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.058400</td>
#       <td>0.837882</td>
#       <td>0.524194</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.049900</td>
#       <td>0.849637</td>
#       <td>0.518145</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.050800</td>
#       <td>0.843623</td>
#       <td>0.519153</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-50
# Configuration saved in wav2vec2-giscard/checkpoint-50/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-50/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-50/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-100
# Configuration saved in wav2vec2-giscard/checkpoint-100/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-100/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-100/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-150
# Configuration saved in wav2vec2-giscard/checkpoint-150/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-150/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-150/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-50] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-200
# Configuration saved in wav2vec2-giscard/checkpoint-200/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-200/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-200/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-100] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-250
# Configuration saved in wav2vec2-giscard/checkpoint-250/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-250/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-250/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-150] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-300
# Configuration saved in wav2vec2-giscard/checkpoint-300/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-300/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-300/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-200] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-350
# Configuration saved in wav2vec2-giscard/checkpoint-350/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-350/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-350/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-250] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-400
# Configuration saved in wav2vec2-giscard/checkpoint-400/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-400/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-400/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-300] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-450
# Configuration saved in wav2vec2-giscard/checkpoint-450/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-450/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-450/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-350] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-500
# Configuration saved in wav2vec2-giscard/checkpoint-500/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-500/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-400] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-550
# Configuration saved in wav2vec2-giscard/checkpoint-550/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-550/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-550/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-450] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-600
# Configuration saved in wav2vec2-giscard/checkpoint-600/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-600/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-600/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-650
# Configuration saved in wav2vec2-giscard/checkpoint-650/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-650/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-650/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-550] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-700
# Configuration saved in wav2vec2-giscard/checkpoint-700/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-700/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-700/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-600] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-750
# Configuration saved in wav2vec2-giscard/checkpoint-750/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-750/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-750/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-650] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-800
# Configuration saved in wav2vec2-giscard/checkpoint-800/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-800/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-800/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-700] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-850
# Configuration saved in wav2vec2-giscard/checkpoint-850/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-850/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-850/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-750] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-900
# Configuration saved in wav2vec2-giscard/checkpoint-900/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-900/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-900/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-800] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 60
#   Batch size = 8
# Saving model checkpoint to wav2vec2-giscard/checkpoint-950
# Configuration saved in wav2vec2-giscard/checkpoint-950/config.json
# Model weights saved in wav2vec2-giscard/checkpoint-950/pytorch_model.bin
# Feature extractor saved in wav2vec2-giscard/checkpoint-950/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-giscard/checkpoint-850] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=960, training_loss=1.188535886692504, metrics={'train_runtime': 716.3154, 'train_samples_per_second': 21.22, 'train_steps_per_second': 1.34, 'total_flos': 1.0426815099977002e+18, 'train_loss': 1.188535886692504, 'epoch': 160.0})

# %% [markdown]
# The final dev WER here is about 0.41.

# %% [markdown]
# ### Evaluate
#
# In the final part, we run our model on some of the validation data to get a feeling for how well it works.
#
# Let's load the `model`. Make sure the model path exists.!

# %%
model = Wav2Vec2ForCTC.from_pretrained("wav2vec2-giscard/checkpoint-950").cuda()
# Out:
# loading configuration file wav2vec2-giscard/checkpoint-950/config.json
# Model config Wav2Vec2Config {
#   "_name_or_path": "facebook/wav2vec2-base",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": false,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": false,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": false,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_norm": "group",
#   "feat_proj_dropout": 0.1,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "freeze_feat_extract_train": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.0,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "no_mask_channel_overlap": false,
#   "no_mask_time_overlap": false,
#   "num_adapter_layers": 3,
#   "num_attention_heads": 12,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 12,
#   "num_negatives": 100,
#   "output_hidden_size": 768,
#   "pad_token_id": 42,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 43,
#   "xvector_output_dim": 512
# }
#
# loading weights file wav2vec2-giscard/checkpoint-950/pytorch_model.bin
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at wav2vec2-giscard/checkpoint-950.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.

# %% [markdown]
# Now, we will make use of the `map(...)` function to predict the transcription of every test sample and to save the prediction in the dataset itself. We will call the resulting dictionary `"results"`.
#
# **Note**: we evaluate the test data set with `batch_size=1` on purpose due to this [issue](https://github.com/pytorch/fairseq/issues/3227). Since padded inputs don't yield the exact same output as non-padded inputs, a better WER can be achieved by not padding the input at all.

# %%
def map_to_result(batch):
    with torch.no_grad():
        input_values = torch.tensor(batch["input_values"]).unsqueeze(0)
        input_values = input_values.cuda()
        logits = model(input_values).logits

    pred_ids = torch.argmax(logits, dim=-1)
    batch["pred_str"] = processor.batch_decode(pred_ids)[0]
    batch["text"] = processor.decode(batch["labels"], group_tokens=False)

    return batch

# %%
results_dev = data["validation"].map(map_to_result, remove_columns=data["validation"].column_names, load_from_cache_file=False)
results_test = data["test"].map(map_to_result, remove_columns=data["test"].column_names, load_from_cache_file=False)
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %% [markdown]
# Let's compute the overall test WER!

# %%
print("Validation WER: {:.3f}".format(wer_metric.compute(predictions=results_dev["pred_str"], references=results_dev["text"])))
# Out:
# Validation WER: 0.475

# %%
print("Test WER: {:.3f}".format(wer_metric.compute(predictions=results_test["pred_str"], references=results_test["text"])))
# Out:
# Test WER: 0.454

# %% [markdown]
# Let's take a look at some predictions to see what errors are made by the model.

# %%
show_random_elements(results_test)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pred_str</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>i should say that he did not lok as he was expeckted to lok his apearense was just tha nothe elemeant of seprise in a serpraising youneverse</td>
#       <td>i should say that he did not look as he was expected to look his appearance was just another element of surprise in a surprising universe</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a person tost int o the north se in decsember would lastd only a few mints be fore freasing to deth and in thes condiiones at might tak an hor to pik up a man om over bored if you could find hem</td>
#       <td>a person tossed into the north sea in december would last only a few minutes before freezing to death and in these conditions it might take an hour to pick up a man overboard if you could find him</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>this time it was ent so founeds a the uothers</td>
#       <td>this time it wasn't so funny to the others</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>yheat the head prograemer a fello named steeve heg retained a sertn dobiuse nes</td>
#       <td>yet the head programmer a fellow named steve hague retained a certain dubiousness</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>the conpor computer sinst oaparemeat had only f55e places</td>
#       <td>the kanpur computer science department had only fifty places</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>the bard was a techino yete fanticsy</td>
#       <td>the bridge was a technogeek fantasy</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>the forse of their atraction was spectacular</td>
#       <td>the force of their attraction was spectacular</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>i meine what he was discribeing was a computer gek</td>
#       <td>i mean what she was describing was a complete geek</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>the sicofantic ton of his eemail to clark scxjested that snel like evrey other venture capitalist fhelt clark needed to be manidghed</td>
#       <td>the sycophantic tone of his email to clark suggested that schnell like every other venture capitalist felt clark needed to be managed</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>ch time wolter lonched ande yot that reputation wentup for grabs</td>
#       <td>each time wolter launched a new yacht that reputation went up for grabs</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It becomes clear that the predicted transcriptions are acoustically very similar to the target transcriptions, but often contain spelling or grammatical errors. This shouldn't be very surprising though given that we purely rely on Wav2Vec2 without making use of a language model.

# %% [markdown]
# Finally, to better understand how CTC works, it is worth taking a deeper look at the exact output of the model. Let's run the first test sample through the model, take the predicted ids and convert them to their corresponding tokens.

# %%
model.to("cuda")

with torch.no_grad():
    logits = model(torch.tensor(data["test"][:1]["input_values"], device="cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)

# convert ids to tokens
" ".join(processor.tokenizer.convert_ids_to_tokens(pred_ids[0].tolist()))
# Out:
# "[PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] b u t t | t h h e r | i i s s | | | n n [PAD] o [PAD] t t h h i n g g | l l [PAD] i i i k e | | s [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] t [PAD] [PAD] [PAD] [PAD] [PAD] n n n | d [PAD] a a a [PAD] [PAD] [PAD] [PAD] [PAD] s s | | | o n | t t h e | | h h [PAD] [PAD] [PAD] [PAD] i y y c c [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] e e [PAD] s s s | | | | | [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] w w i t t h | a | | s s [PAD] m m m a a l [PAD] l l | | g r r r o o o p | | o o f | | | p [PAD] e e e e o o p p l l l l e e e e | | | w h h [PAD] o o o | | | h h h a a a v v | | a | | l l [PAD] o o o [PAD] t | o f f | | d d [PAD] [PAD] [PAD] [PAD] o u u t t s e | a a b b [PAD] o o u t t | e e e t c h h e e u u [PAD] t h h e e r r r | | | | [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] t t o o | t t e e e e s s t t t | | w o o o [PAD] [PAD] [PAD] n n ' s | | | a a s s s s [PAD] [PAD] o o o m m t t t i i i o o n n s s s | | | a b b [PAD] [PAD] o u u t t | h h h [PAD] o o m m a n a n | | c c a a a a r r r r r c t t t e e e r r | | | [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]"

# %% [markdown]
# The output should make it a bit clearer how CTC works in practice. The model is to some extent invariant to speaking rate since it has learned to either just repeat the same token in case the speech chunk to be classified still corresponds to the same token. This makes CTC a very powerful algorithm for speech recognition since the speech file's transcription is often very much independent of its length.
